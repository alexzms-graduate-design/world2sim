# %%
import mph

client = mph.start()
model = client.load("./transient_real_pressure.mph")
mph.tree(model)
print(model.parameters())
# Out:
# transient_real_pressure
# ├─ parameters
# │  └─ 参数 1
# ├─ functions
# │  ├─ freq2w函数
# │  ├─ 生成随时间变化的频率 扫频信号
# │  ├─ 法相速度
# │  ├─ 法相速度 衰减
# │  ├─ 法相速度 恒常
# │  └─ 降噪喇叭 法相速度
# ├─ components
# │  └─ 组件 1
# ├─ geometries
# │  └─ 几何 1
# │     ├─ 导入 1
# │     ├─ 点 1
# │     ├─ source_point
# │     └─ 形成联合体
# ├─ views
# │  └─ 视图 1
# ├─ selections
# ├─ coordinates
# │  └─ 边界坐标系 1
# ├─ variables
# ├─ couplings
# │  └─ 积分算子
# ├─ physics
# │  └─ 压力声学，瞬态
# │     ├─ 瞬态压力声学模型 1
# │     ├─ 硬声场边界（壁） 1
# │     ├─ 初始值 1
# │     ├─ 连续性 1
# │     ├─ 阻抗 1
# │     ├─ 软声场边界 1 open_boundary
# │     ├─ 压力 noise_signal
# │     ├─ 压力 denoise_signal
# │     └─ 压力 1
# ├─ multiphysics
# ├─ materials
# │  └─ Air
# │     ├─ Basic
# │     ├─ Refractive index
# │     ├─ Nonlinear model
# │     └─ Ideal gas
# ├─ meshes
# │  └─ 网格 1
# │     ├─ 大小
# │     ├─ 大小 1
# │     ├─ 大小表达式 1
# │     └─ 自由四面体网格 1
# ├─ studies
# │  └─ 研究 1
# │     └─ 瞬态
# ├─ solutions
# │  └─ 解 1
# │     ├─ 编译方程: 瞬态
# │     ├─ 因变量 1
# ...

# %%
model.build()
model.solve("研究 1")

# %%
model.export("plot1", "test2.csv")
